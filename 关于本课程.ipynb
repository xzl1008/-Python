# %% [markdown]
# <table border="0" width="100%"><tr><td><p align="left"><img src="Images/logo.png" align="left" width="300"></p></td><td><font size="5">Python程序设计与应用</font></td></tr></table>

# %% [markdown]
# # <div align="center">关于本课程的说明</div>

# %% [markdown]
# # 1. 计算机公共基础课程：
# * **第一学期**：学计算机基础（解决计算机操作的问题）
# * **第二学期**：程序设计（解决计算机应用的问题）

# %% [markdown]
# # 2. 课程考核
# ### 期末考试(70%)：
# * **考核内容：** 教学内容中需要理解和掌握的内容；考察学生的自主学习能力；考察学生的程序设计应用能力
# * **考核方式：** <font color=red>笔试（闭卷）</font>，由课程组统一组织命题。
# * **占比分值：** 70分
#
# ### 平时成绩(30%)：
#
# |考试形式|说明|考察方式|分值|
# |----|:--|----|--|
# |教学过程|包括：考勤、讨论、回答问题、课堂作业、在线测试|方式由任课老师自主决定|5分|
# |课堂测试|不少于3次的课堂随机测试和1次期中考试|方式由任课老师自主决定|15分|
# |课后作业|全学期不少于5次|方式由任课老师自主决定|10分|

# %% [markdown]
# # 3. 联系方式
# ### 谢志龙
# ### 作业邮箱：xzl_swufe@163.com
# ### QQ群：
